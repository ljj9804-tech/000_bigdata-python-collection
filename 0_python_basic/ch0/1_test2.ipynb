# %%
print("hello python")
# Out:
# hello python

# %%
import sys
print("파이썬 버전:", sys.version)
# Out:
# 파이썬 버전: 3.14.5 (tags/v3.14.5:5607950, May 10 2026, 10:43:50) [MSC v.1944 64 bit (AMD64)]

# %%
print("이진주")
# Out:
# 이진주

# %%
print("★ " * 5)   # 문자열 * 숫자 = 반복
# 결과: *****
# Out:
# ★ ★ ★ ★ ★
